# %%
import pandas as pd

# %% [markdown]
# I imported the pandas library and aliased it as 'pd'.

# %% [markdown]
# Now I'm going to 'import' the .csv file, so I can view it and work on it here

# %% [markdown]
# We can choose to import the .csv file using the full path (procceded by a / with the working directory) or the relative file path.
# The read.csv fucntion is able to decipher between the two, so it doesn't matter.

# %%
df = pd.read_csv('Mental_Health_Care.csv')
df
# Out:
#                                               Indicator              Group  \
# 0     Took Prescription Medication for Mental Health...  National Estimate
# 1     Took Prescription Medication for Mental Health...             By Age
# 2     Took Prescription Medication for Mental Health...             By Age
# 3     Took Prescription Medication for Mental Health...             By Age
# 4     Took Prescription Medication for Mental Health...             By Age
# ...                                                 ...                ...
# 4779  Needed Counseling or Therapy But Did Not Get I...           By State
# 4780  Needed Counseling or Therapy But Did Not Get I...           By State
# 4781  Needed Counseling or Therapy But Did Not Get I...           By State
# 4782  Needed Counseling or Therapy But Did Not Get I...           By State
# 4783  Needed Counseling or Therapy But Did Not Get I...           By State
#
# ...

# %% [markdown]
# Scoping the data:
# I already see from the first couple of rows that's we have some missing values in our dataset... I want to see how many empty values we actually have with .isnull() or .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4784 entries, 0 to 4783
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Indicator               4784 non-null   object
#  1   Group                   4784 non-null   object
#  2   State                   4784 non-null   object
#  3   Subgroup                4784 non-null   object
#  4   Phase                   4784 non-null   object
#  5   Time Period             4784 non-null   int64
#  6   Time Period Label       4784 non-null   object
#  7   Time Period Start Date  4784 non-null   object
#  8   Time Period End Date    4784 non-null   object
#  9   Value                   4609 non-null   float64
#  10  LowCI                   4609 non-null   float64
#  11  HighCI                  4609 non-null   float64
#  12  Confidence Interval     4609 non-null   object
#  13  Quartile Range          3264 non-null   object
# ...

# %% [markdown]
# So we can see there's a plethora of missing information. There's supposed to be 4784 entires for each column, but we can see that's not true for some of the columns. We see that there are 175 missing values (4784-4609) in
# the columns, Value, LowCI, HighCI(which I'm assuming stands for confidence interval)& Confidence Interval.
# -Then there's way more missing in the Quartile range and Suppresion flag.

# %% [markdown]
# Data Cleaning -Maintaing Data Integrity:
# So I'm going to be making a new dataframe(a copy of the original one), where I'm free to make changes without messing with the original dataframe.
#
# We'll name this new frame 'df1'. I'll be deleting the null values by dropping all of the columns with null values.
#
# Then after looking at the column names, I want to make a few changes like shorten 'Time Period Start date' and 'Time Period End Date' to just 'Start Date' and 'End Date'.

# %%
df1 = df.dropna(axis = 'columns') #dropping columns with null values
#can also be written as df.dropna(axis= 1), will not use inplace = False because that's the default. 
#Nor will I be using inplace = True because not committing changes to the orginal dataset.
df1.shape
# Out:
# (4784, 9)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4784 entries, 0 to 4783
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Indicator               4784 non-null   object
#  1   Group                   4784 non-null   object
#  2   State                   4784 non-null   object
#  3   Subgroup                4784 non-null   object
#  4   Phase                   4784 non-null   object
#  5   Time Period             4784 non-null   int64
#  6   Time Period Label       4784 non-null   object
#  7   Time Period Start Date  4784 non-null   object
#  8   Time Period End Date    4784 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 336.5+ KB

# %% [markdown]
# Here, we can see that we no longer have any null values present. Time to change the column names

# %%
df1 = df1.rename(columns={'Time Period Start Date': 'Start Date','Time Period End Date': 'End Date'})
df1
# Out:
#                                               Indicator              Group  \
# 0     Took Prescription Medication for Mental Health...  National Estimate
# 1     Took Prescription Medication for Mental Health...             By Age
# 2     Took Prescription Medication for Mental Health...             By Age
# 3     Took Prescription Medication for Mental Health...             By Age
# 4     Took Prescription Medication for Mental Health...             By Age
# ...                                                 ...                ...
# 4779  Needed Counseling or Therapy But Did Not Get I...           By State
# 4780  Needed Counseling or Therapy But Did Not Get I...           By State
# 4781  Needed Counseling or Therapy But Did Not Get I...           By State
# 4782  Needed Counseling or Therapy But Did Not Get I...           By State
# 4783  Needed Counseling or Therapy But Did Not Get I...           By State
#
# ...

# %%
df1.columns
# Out:
# Index(['Indicator', 'Group', 'State', 'Subgroup', 'Phase', 'Time Period',
#        'Time Period Label', 'Start Date', 'End Date'],
#       dtype='object')

# %% [markdown]
# Okay so we have so many rows that I can't physically scroll all the way down to see all of the unique values of the Indicator column. From looking throught the data, the Indicator column is a defining column of our dataset, so I wan't to see the unique values.
# So in order to do that I'll use .unique() for that column, and other columns to just to gage more about my data.

# %%
df1.Indicator.unique()
# Out:
# array(['Took Prescription Medication for Mental Health, Last 4 Weeks',
#        'Received Counseling or Therapy, Last 4 Weeks',
#        'Took Prescription Medication for Mental Health And/Or Received Counseling or Therapy, Last 4 Weeks',
#        'Needed Counseling or Therapy But Did Not Get It, Last 4 Weeks'],
#       dtype=object)

# %%
type(df1.Indicator.head())
# Out:
# pandas.core.series.Series

# %%
df1['Indicator'] #we can also use the brackets to pull out a single column, but it's not effective in viewing unique values
# Out:
# 0       Took Prescription Medication for Mental Health...
# 1       Took Prescription Medication for Mental Health...
# 2       Took Prescription Medication for Mental Health...
# 3       Took Prescription Medication for Mental Health...
# 4       Took Prescription Medication for Mental Health...
#                               ...
# 4779    Needed Counseling or Therapy But Did Not Get I...
# 4780    Needed Counseling or Therapy But Did Not Get I...
# 4781    Needed Counseling or Therapy But Did Not Get I...
# 4782    Needed Counseling or Therapy But Did Not Get I...
# 4783    Needed Counseling or Therapy But Did Not Get I...
# Name: Indicator, Length: 4784, dtype: object

# %%
df1.State.unique()
# Out:
# array(['United States', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df1.Group.unique()
# Out:
# array(['National Estimate', 'By Age', 'By Sex',
#        'By Presence of Symptoms of Anxiety/Depression',
#        'By Race/Hispanic ethnicity', 'By Education', 'By State',
#        'By Disability status'], dtype=object)

# %%
df1.Subgroup.unique()
# Out:
# array(['United States', '18 - 29 years', '30 - 39 years', '40 - 49 years',
#        '50 - 59 years', '60 - 69 years', '70 - 79 years',
#        '80 years and above', 'Male', 'Female',
#        'Did not experience symptoms of anxiety/depression in the past 4 weeks',
#        'Experienced symptoms of anxiety/depression in past 4 weeks',
#        'Hispanic or Latino', 'Non-Hispanic White, single race',
#        'Non-Hispanic Black, single race',
#        'Non-Hispanic Asian, single race',
#        'Non-Hispanic, other races and multiple races',
#        'Less than a high school diploma', 'High school diploma or GED',
#        "Some college/Associate's degree", "Bachelor's degree or higher",
#        'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
# ...

# %%
df1[df1.Subgroup == '18 - 29 years']
# Out:
#                                               Indicator   Group  \
# 1     Took Prescription Medication for Mental Health...  By Age
# 73         Received Counseling or Therapy, Last 4 Weeks  By Age
# 145   Took Prescription Medication for Mental Health...  By Age
# 217   Needed Counseling or Therapy But Did Not Get I...  By Age
# 289   Took Prescription Medication for Mental Health...  By Age
# ...                                                 ...     ...
# 4521       Received Counseling or Therapy, Last 4 Weeks  By Age
# 4595  Took Prescription Medication for Mental Health...  By Age
# 4616  Took Prescription Medication for Mental Health...  By Age
# 4690  Needed Counseling or Therapy But Did Not Get I...  By Age
# 4711  Needed Counseling or Therapy But Did Not Get I...  By Age
#
#               State       Subgroup Phase  Time Period Time Period Label  \
# 1     United States  18 - 29 years     2           13   Aug 19 - Aug 31
# ...

# %% [markdown]
# The above code can also be written as df2['Subgroup'] == '18 - 29 years'. It'll also return a bool type output.
# In order to get a non bool type output and the actual values, place [] around the entire filered object code and apply it to your dataframe: df2[df2['Subgroup'] == '18 - 29 years']

# %%
df1[df1.State == 'New York']
# Out:
#                                               Indicator     Group     State  \
# 53    Took Prescription Medication for Mental Health...  By State  New York
# 125        Received Counseling or Therapy, Last 4 Weeks  By State  New York
# 197   Took Prescription Medication for Mental Health...  By State  New York
# 269   Needed Counseling or Therapy But Did Not Get I...  By State  New York
# 341   Took Prescription Medication for Mental Health...  By State  New York
# ...                                                 ...       ...       ...
# 4385  Needed Counseling or Therapy But Did Not Get I...  By State  New York
# 4480  Took Prescription Medication for Mental Health...  By State  New York
# 4575       Received Counseling or Therapy, Last 4 Weeks  By State  New York
# 4670  Took Prescription Medication for Mental Health...  By State  New York
# 4765  Needed Counseling or Therapy But Did Not Get I...  By State  New York
#
# ...

# %% [markdown]
# So what do I want to filter from this data to be able to analyze? I want to be able to return only specific information of a value in a column. I want to filter the data in which the State has the value 'New York' and the Subgroup has the values is '18-29 years'.
#
# So i'll be making a variable in order to filter the set. I want to go ahead and put this new filtered set into a seperate dataframe, which I'll call 'df2'.

# %%
df2 = df1[(df1.Subgroup == '18 - 29 years') | (df1.State == 'New York')]
df2
#Similar code df2 = df1.loc[(df1.Subgroup == '18 - 29 years') | (df1.State == 'New York')]
# group = ['18 - 29 years', 'New York'] 
# df2[df2['Subgroup'].isin(group)]
# Out:
#                                               Indicator     Group  \
# 1     Took Prescription Medication for Mental Health...    By Age
# 53    Took Prescription Medication for Mental Health...  By State
# 73         Received Counseling or Therapy, Last 4 Weeks    By Age
# 125        Received Counseling or Therapy, Last 4 Weeks  By State
# 145   Took Prescription Medication for Mental Health...    By Age
# ...                                                 ...       ...
# 4616  Took Prescription Medication for Mental Health...    By Age
# 4670  Took Prescription Medication for Mental Health...  By State
# 4690  Needed Counseling or Therapy But Did Not Get I...    By Age
# 4711  Needed Counseling or Therapy But Did Not Get I...    By Age
# 4765  Needed Counseling or Therapy But Did Not Get I...  By State
#
#               State       Subgroup Phase  Time Period Time Period Label  \
# 1     United States  18 - 29 years     2           13   Aug 19 - Aug 31
# ...

# %% [markdown]
# In order to filter two values, you need to create a list. So I'm going to create a variable that contains the lists of filtered values, then use " .isin() " to apply it to my filtering code. Pandas isin() is used to filter data frames and selects the rows that have particular values in a given column.

# %%
group = ['18 - 29 years', 'New York'] 
df2[df2['Subgroup'].isin(group)]
# Out:
#                                               Indicator     Group  \
# 1     Took Prescription Medication for Mental Health...    By Age
# 53    Took Prescription Medication for Mental Health...  By State
# 73         Received Counseling or Therapy, Last 4 Weeks    By Age
# 125        Received Counseling or Therapy, Last 4 Weeks  By State
# 145   Took Prescription Medication for Mental Health...    By Age
# ...                                                 ...       ...
# 4616  Took Prescription Medication for Mental Health...    By Age
# 4670  Took Prescription Medication for Mental Health...  By State
# 4690  Needed Counseling or Therapy But Did Not Get I...    By Age
# 4711  Needed Counseling or Therapy But Did Not Get I...    By Age
# 4765  Needed Counseling or Therapy But Did Not Get I...  By State
#
#               State       Subgroup Phase  Time Period Time Period Label  \
# 1     United States  18 - 29 years     2           13   Aug 19 - Aug 31
# ...

# %% [markdown]
# the .loc() fucntions allows you to filter out specific columns and also to add particular parameters to the filter.
# For example to filter out columns for the data to be more concise, like what we did above.
# We used the .loc() function to pass the two columns as the parameters that we wanted to see data in.

# %%
df2.loc[(df.Phase >= '2'),['Indicator','Phase']]
# Out:
#                                               Indicator Phase
# 1     Took Prescription Medication for Mental Health...     2
# 53    Took Prescription Medication for Mental Health...     2
# 73         Received Counseling or Therapy, Last 4 Weeks     2
# 125        Received Counseling or Therapy, Last 4 Weeks     2
# 145   Took Prescription Medication for Mental Health...     2
# ...                                                 ...   ...
# 4575       Received Counseling or Therapy, Last 4 Weeks   3.1
# 4616  Took Prescription Medication for Mental Health...   3.1
# 4670  Took Prescription Medication for Mental Health...   3.1
# 4711  Needed Counseling or Therapy But Did Not Get I...   3.1
# 4765  Needed Counseling or Therapy But Did Not Get I...   3.1
#
# [128 rows x 2 columns]

# %%
#We want to return Indicator and Subgroup information, where the subgroup is 18-29 years
df2.loc[(df2.Subgroup == '18 - 29 years'),['Indicator','Subgroup']].head()
# Out:
#                                              Indicator       Subgroup
# 1    Took Prescription Medication for Mental Health...  18 - 29 years
# 73        Received Counseling or Therapy, Last 4 Weeks  18 - 29 years
# 145  Took Prescription Medication for Mental Health...  18 - 29 years
# 217  Needed Counseling or Therapy But Did Not Get I...  18 - 29 years
# 289  Took Prescription Medication for Mental Health...  18 - 29 years

# %%
df2.loc[df2['Subgroup'].isin(['18 - 29 years', 'New York']),['Indicator','Subgroup']].head()
# Out:
#                                              Indicator       Subgroup
# 1    Took Prescription Medication for Mental Health...  18 - 29 years
# 53   Took Prescription Medication for Mental Health...       New York
# 73        Received Counseling or Therapy, Last 4 Weeks  18 - 29 years
# 125       Received Counseling or Therapy, Last 4 Weeks       New York
# 145  Took Prescription Medication for Mental Health...  18 - 29 years

# %%
group = ['18 - 29 years', 'New York']
df2.loc[df2['Subgroup'].isin(group),['Indicator','Subgroup']].head()
# Out:
#                                              Indicator       Subgroup
# 1    Took Prescription Medication for Mental Health...  18 - 29 years
# 53   Took Prescription Medication for Mental Health...       New York
# 73        Received Counseling or Therapy, Last 4 Weeks  18 - 29 years
# 125       Received Counseling or Therapy, Last 4 Weeks       New York
# 145  Took Prescription Medication for Mental Health...  18 - 29 years

# %%
deleted = ['Start Date', 'End Date', 'Time Period', 'Phase']
df3 = df2.drop(deleted, axis = 1)
df3

#other ways to write this line of code
# df3 = df2.drop(['Start Date', 'End Date'], 1)
# df3 = df2.drop(columns = ['Start Date','End Date'],axis = 1)
# df3 = df2.drop(['Start Date', 'End Date'], axis = 1)
# Out:
#                                               Indicator     Group  \
# 1     Took Prescription Medication for Mental Health...    By Age
# 53    Took Prescription Medication for Mental Health...  By State
# 73         Received Counseling or Therapy, Last 4 Weeks    By Age
# 125        Received Counseling or Therapy, Last 4 Weeks  By State
# 145   Took Prescription Medication for Mental Health...    By Age
# ...                                                 ...       ...
# 4616  Took Prescription Medication for Mental Health...    By Age
# 4670  Took Prescription Medication for Mental Health...  By State
# 4690  Needed Counseling or Therapy But Did Not Get I...    By Age
# 4711  Needed Counseling or Therapy But Did Not Get I...    By Age
# 4765  Needed Counseling or Therapy But Did Not Get I...  By State
#
#               State       Subgroup Time Period Label
# 1     United States  18 - 29 years   Aug 19 - Aug 31
# 53         New York       New York   Aug 19 - Aug 31
# ...

# %%
df3
# Out:
#                                               Indicator     Group  \
# 1     Took Prescription Medication for Mental Health...    By Age
# 53    Took Prescription Medication for Mental Health...  By State
# 73         Received Counseling or Therapy, Last 4 Weeks    By Age
# 125        Received Counseling or Therapy, Last 4 Weeks  By State
# 145   Took Prescription Medication for Mental Health...    By Age
# ...                                                 ...       ...
# 4616  Took Prescription Medication for Mental Health...    By Age
# 4670  Took Prescription Medication for Mental Health...  By State
# 4690  Needed Counseling or Therapy But Did Not Get I...    By Age
# 4711  Needed Counseling or Therapy But Did Not Get I...    By Age
# 4765  Needed Counseling or Therapy But Did Not Get I...  By State
#
#               State       Subgroup Time Period Label
# 1     United States  18 - 29 years   Aug 19 - Aug 31
# 53         New York       New York   Aug 19 - Aug 31
# ...

# %%
df3.sort_values(by = ['Indicator', 'Subgroup'], inplace = True)
df3
# Out:
#                                               Indicator     Group  \
# 217   Needed Counseling or Therapy But Did Not Get I...    By Age
# 505   Needed Counseling or Therapy But Did Not Get I...    By Age
# 793   Needed Counseling or Therapy But Did Not Get I...    By Age
# 1081  Needed Counseling or Therapy But Did Not Get I...    By Age
# 1369  Needed Counseling or Therapy But Did Not Get I...    By Age
# ...                                                 ...       ...
# 3305  Took Prescription Medication for Mental Health...  By State
# 3593  Took Prescription Medication for Mental Health...  By State
# 3881  Took Prescription Medication for Mental Health...  By State
# 4169  Took Prescription Medication for Mental Health...  By State
# 4480  Took Prescription Medication for Mental Health...  By State
#
#               State       Subgroup Time Period Label
# 217   United States  18 - 29 years   Aug 19 - Aug 31
# 505   United States  18 - 29 years    Sep 2 - Sep 14
# ...
